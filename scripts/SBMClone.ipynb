# %%
# Reads the "ground truth" mapping from cell id to cell cluster, as provided by Chisel in a TSV file, available at:
# https://github.com/raphael-group/chisel-data/blob/master/patientS0/clones/all/mapping.tsv.gz
# builds a set of healthy cells

print('Reading ground truth clustering and creating Healthy cell list')
cell_to_clone = open('/Users/dd/work/svc/data/mapping_all.tsv')
# cell_to_clone.readline()  # skip header (I just deleted the first line instead)

healthy_cell_ids = set()
clone_name_to_idx = {}  # maps Chisel clone names to a 0-based idx, e.g. {'Clone401':0, 'Clone2535':1}
cell_id_to_clone_idx = {}  # stores {cell_id, clone_idx} pairs, e.g. {'A-AAACCTGAGATCTGCT' : 0, 'A-AAACCTGGTACCGCTG':1}
clone_idx = 0


for line in cell_to_clone:
    els = line.split('\t')
    clone_name = els[2]
    if els[1] == '2535':
        healthy_cell_ids.add(els[0])
        continue
    if clone_name not in clone_name_to_idx:
        clone_name_to_idx[clone_name] = clone_idx
        clone_idx += 1
    cell_id = els[0]
    cell_id_to_clone_idx[cell_id] = clone_name_to_idx[clone_name]



print(f'Found {len(healthy_cell_ids)} healthy cells, {len(cell_id_to_clone_idx)} tumor cells')
# Out:
# Reading ground truth clustering and creating Healthy cell list
# Found 4239 healthy cells, 5963 tumor cells

# %%
import csv

# reading the 40K mutations identified in the Breast Cancer dataset by Chisel (from a TSV file), available at:
# https://github.com/raphael-group/chisel-data/blob/master/patientS0/snvs/cellmutations.tsv.gz
# and then remove all mutations that are also appearing in at least one healthy cell
# Keep only the cell ids that have at least one mutation after this filtering (some tumor cells may only show mutations
# that are in common with at least one healthy cell)

print('Filtering out mutations found in healthy cells')
mutations = []

tsv_all_mut = open('/Users/dd/Downloads/cellmutations.tsv')
read_tsv_all_mut = csv.reader(tsv_all_mut, delimiter='\t')
next(read_tsv_all_mut, None)  # skip header

cell_ids_with_mutations = set()

for row in read_tsv_all_mut:
    cell_ids = row[5].split(',')
    # cell_ids = [c[2:] for c in cell_ids] # remove the A- prefix
    healthy_count = 0
    for cell_id in cell_ids:
        if cell_id in healthy_cell_ids:
            healthy_count += 1

    if healthy_count >= 1:
        continue

    chromosome = row[0]
    pos = row[1]
    cell_ids_with_mutations.update(cell_ids)
    mutations.append((chromosome, pos, cell_ids))

print(f'Found {len(cell_ids_with_mutations)} tumor cells that have no mutations in common with healthy cells')
print(f'Found {len(mutations)} cancer mutations: {mutations}')

cell_id_to_idx = {}  # maps cell ids to a 0-based index
cell_idx_to_id = {}  # the inverse of cell_id_to_idx
cell_idx = 0
for cell_id in cell_ids_with_mutations:
    if cell_id in healthy_cell_ids:
        continue
    cell_id_to_idx[cell_id] = cell_idx
    cell_idx_to_id[cell_idx] = cell_id
    cell_idx += 1
# Out:
# Filtering out mutations found in healthy cells
# Found 4068 tumor cells that have no mutations in common with healthy cells
# Found 10551 cancer mutations: [('chr1', '789057', ['D-AGATTGCCAGTGCTTA', 'E-GACTAACTCTGGCCTT', 'E-TGACGGCCAGTGCTGC']), ('chr1', '790488', ['C-TCACGAAGTGTGACAG', 'D-CGTGTAAAGTGAACAT', 'E-GGATTACCACCTCCAT']), ('chr1', '790956', ['D-AAGACCTGTTCCCTAC']), ('chr1', '790958', ['B-ACGGGTCAGTTCGATC', 'C-GAAGCAGGTCTGCCAG', 'C-GGCAATTGTAGAATAC', 'E-CGGAGCTCATCTTTCA']), ('chr1', '1222922', ['E-AGTGTCAGTTCTAGAC', 'E-TCATTACGTCAAGTCT']), ('chr1', '1321057', ['E-AACTCTTAGTCCGGTC', 'E-ACCGTAACACCCGTTT']), ('chr1', '1455915', ['D-GCTGGGTAGAAACCTA', 'E-CCGGTAGCATGAGGGT', 'E-GAACATCTCTTCACGC', 'E-TACTTGTCAACTTTCT']), ('chr1', '2653150', ['E-TCTTCGGAGTACTTGC']), ('chr1', '2653238', ['B-TTGACTTAGTGGCACA', 'C-CACTCCATCGGAGAAC', 'D-ATCACGACAGCGCATC', 'E-ACTTTCAAGGCCCGTT']), ('chr1', '2653404', ['C-ATCATCTCAAGTGTTC']), ('chr1', '2653875', ['E-CAGTAACAGAACTCGG', 'E-GGCCGATAGAGCTGCA']), ('chr1', '2657154', ['C-ACACCCTTCATTGGAC', 'C-TTGCCGTAGATCCGAG', 'E-AGGCCACGTGCGGTAA', 'E-TTCCCAGGTAGTGACG']), ('chr1', '2674954', ['C-ATAGACCTCGACAACT', 'C-CATCAAGAGGCTCTTA', 'E-GATGCTAAGAGTCTGG']), ('chr1', '2688424', ['C-TAGGCATGTCAGCCGT', 'E-GGATGTTAGAGGTAGA', 'E-TGACTTTTCGTTGCTC']), ('chr1', '2694792', ['B-GTATTCTCAGGATCCC', 'C-CGACCTTAGCTAGCCC', 'C-TTAGTTCAGACCCACC', 'D-AAGGAGCTCTCGAACA', 'D-GGCCGATTCTGCTAGA', 'E-CGTTAGACACGCTGAC']), ('chr1', '2985022', ['E-ATGCGATTCGCGGACT', 'E-CCTACCATCTGGTGGC', 'E-CGAGCACCACTCACCT', 'E-CGTAGCGGTAGGGTGT', 'E-GTTCATTAGGTGTGGT', 'E-TGTCCCAAGAGTCCTT', 'E-TTTGCGCTCGTATTGG']), ('chr1', '3337628', ['E-GGACAAGCATGGCTAT']), ('chr1', '3470907', ['B-ATTACTCGTGGTGAGT', 'C-CATTCGCCACCCGTTT', 'E-AAGACCTTCGATACAC']), ('chr1', '3888781', ['E-CTCGAGGTCGAGTATC', 'E-GTTACAGCAACCCACG', 'E-TGGACGCCAGGGAAGG']), ('chr1', '3906405', ['E-CTACGTCGTCCAGTGC', 'E-TCTTCGGAGTACTTGC']), ('chr1', '4268041', ['E-CTGCCTAAGAGACTTA', 'E-TCCACACGTGTCAACT']), ('chr1', '4533556', ['B-CCTACCAAGCACAGGT', 'B-TCATTACAGAAACCTA', 'D-ATTTCTGGTCAGTTTG', 'D-TAGCCGGTCAACGATC']), ('chr1', '5112431', ['E-CACACTCAGGTAACGC', 'E-CGTGTAACAGAAGAAG']), ('chr1', '6022476', ['D-TGACGGCTCAGAAACA', 'E-AGGGAGTGTGATTGTC', 'E-GGGTCTGCAACAACTC']), ('chr1', '6034130', ['E-GCAATCACATAGAGGC', 'E-GGATTACTCTCATACT']), ('chr1', '6467049', ['E-AAGACCTTCAATAGGA', 'E-TTTGGTTGTTAAAGGT']), ('chr1', '8788571', ['E-CTAACTTGTAAGTAAC', 'E-GCATGATGTGATAAGT', 'E-TACGGGCAGAACTTCC', 'E-TGAGCATGTACTACAC']), ('chr1', '10164236', ['C-CGAATGTGTTCCACAA', 'D-CGATGTATCTGGTCCT', 'D-TGTATTCGTCGCTCAG', 'D-TGTCCCAAGGGTGTTG']), ('chr1', '10767273', ['C-AAGCCGCGTGACGGTA', 'E-AAAGCAATCGAGAATA', 'E-CTGGTCTGTTGCGGCT']), ('chr1', '11373908', ['E-CTACCCAGTAGTGACG']), ('chr1', '11585573', ['E-CTGCTGTCACGGGATA', 'E-TATGCCCGTATGAAAC']), ('chr1', '12822259', ['E-CCACTACCATAGGTCT', 'E-TGGGCGTGTCGACGCT']), ('chr1', '13229469', ['C-TAAGTGCGTCCGGTGT', 'D-CTGATCCGTAATGACA', 'E-ACGCCGATCAACTGCA', 'E-CCACTACCATAGGTCT', 'E-GCGACCATCGTTATCT']), ('chr1', '13232834', ['D-ACATGGTAGTCTAGCT', 'D-CTGCTGTAGAGTAATC']), ('chr1', '13434220', ['D-GTGCAGCGTTGCCAAT', 'E-AGATTGCCAAATCGCT', 'E-GCATGTAAGTACGACG']), ('chr1', '14735046', ['E-AGGGAGTGTAGCAGTG', 'E-CCATTCGTCTTGTTAC']), ('chr1', '14988176', ['B-GAGGTGAAGGCTCTTA', 'E-CGCCAAGTCGATTGCA', 'E-TATCAGGGTACGCGAA']), ('chr1', '15066697', ['D-GTCACGGTCTCGGTTC', 'E-CTGATCCCAAGGGATC', 'E-GTTCATTAGGTGTGGT']), ('chr1', '15435442', ['B-ACGCCGACATTATCGG', 'D-CAGAATCTCTTCACAT', 'D-CTCTGGTTCGCACAGC', 'E-CAGTCCTCAAATCGCT']), ('chr1', '15519336', ['C-AACCATGCAGAACAGC', 'C-AGGGAGTTCTAAGACC', 'C-CCATTCGTCACTGCGG', 'C-CCTTACGCAGAGATCG', 'C-CTCTAATTCCTGATTT', 'C-CTTCTCTAGGCAAAGA', 'C-TCAACGACATACAGAA', 'C-TTTCCTCAGCTGGTCC']), ('chr1', '15844681', ['E-AGGTCATGTTTGTCAG', 'E-CCCAATCCAGAACAGC']), ('chr1', '15987471', ['B-AGTTGGTTCGCTGAAT', 'E-ATCGAGTGTCCAGTGC', 'E-CGTAGGCCATGTTTCT']), ('chr1', '16408864', ['E-GGGAATGTCCGCCTTA', 'E-TCACGAACAGCGCATC']), ('chr1', '16508810', ['C-TGACGGCAGTTGGCTT', 'D-TCAGATGGTTTACTTC', 'E-AGTCTTTGTCTTGCGG', 'E-CTAATGGGTTGAACTC']), ('chr1', '16581751', ['E-GGAACTTAGCTTCAGT', 'E-TATCAGGGTACGCGA ...

# %%
# Generate a mapping that groups multiple cells together based on the Chisel "ground truth"
# This way we can simulate higher coverage in silico

# how many cells of the same type to merge together
merge_count = 10

print(f'Grouping {merge_count} cells together in order to increase coverage')

cell_id_to_group = {}
id_to_count = {}
group_count = 0

for cell_idx in range(len(cell_idx_to_id)):
    cell_id = cell_idx_to_id[cell_idx]
    clone_idx = cell_id_to_clone_idx[cell_id]
    if clone_idx not in id_to_count:
        id_to_count[clone_idx] = []

    id_to_count[clone_idx].append(cell_id)

    if len(id_to_count[clone_idx]) == merge_count:
        for cell_id in id_to_count[clone_idx]:
            cell_id_to_group[cell_id] = group_count
        group_count += 1
        del id_to_count[clone_idx]

print(f'Creating {group_count} complete groups and {len(id_to_count)} incomplete groups')

print(id_to_count.values())

# add incomplete groups
for cells in id_to_count.values():
    for cell_id in cells:
        cell_id_to_group[cell_id] = group_count
    group_count += 1

print(f'Group count is {group_count}')
# Out:
# Grouping 10 cells together in order to increase coverage
# Creating 403 complete groups and 7 incomplete groups
# dict_values([['B-CGGACGTTCCCACGGA', 'E-GCGCAACCAAATACGA', 'E-GATGAAACACACGCAC', 'E-CAGATCATCACTTTAC', 'E-AAAGCAACATTTCTTG', 'E-ATAGACCTCTAACACG', 'E-TCCACACCAACGGCTC', 'E-CACACCTCACGAGCTC', 'C-TCGGGACGTAGCGTCC'], ['E-AACACGTGTACGTTTG', 'C-AGGGTGAGTGCTATTG', 'B-CTCAGAAAGCACAGGT', 'B-CGGCTAGTCGGTAAGG', 'B-CCGGTAGAGGAGTAGA', 'B-GCAATCAAGCGACGTA', 'C-AGTCTTTTCGTGAGGA', 'B-CGGACTGCAGTCCGCA', 'B-AAACCTGAGTAATCCC'], ['E-CTCGAGGTCGAGTATC', 'E-AGCATACGTCTCTATT', 'C-AGCGTCGAGATTACCC', 'B-ACACCAAGTCAAGTTC', 'E-GTGCTTCCACCAGTGC', 'C-CTCGAAAAGTCCCACG', 'E-CGATTGACAATAACAG', 'B-AGTGAGGAGTTAGCGG'], ['E-GCTGCTTTCCGCTTGT', 'D-CTACGTCAGCATGGCA', 'E-CAAGATCCACTATGCA', 'E-CGTCAGGCACTCTCTG', 'D-TGTCCCAGTCAGAAGC', 'E-GCGCAACTCGAGCACC', 'B-ACATGGTCATAGTGAA'], ['E-TTCCCAGAGATCGGGT', 'E-CACATAGCAAGCATGG'], ['C-TCACGAACACCTATGA', 'E-AACTGGTCAATCGCGC'], ['E-GCTCTGTCAGGACCAA']])
# Group count is 410

# %%
print('Creating SBMClone input file...')

sbm_file = open('/Users/dd/work/svc/data/sbm_input', 'w')
all_group_ids = set()
el_count = 0
for count, mutation in enumerate(mutations):
    cell_ids = mutation[2]
    group_ids = set()  # two cells may map to the same group which would cause duplicate entries that upset SBMClone
    for cell_id in cell_ids:
        group_id = cell_id_to_group[cell_id]
        if group_id not in group_ids:
            group_ids.add(group_id)
            sbm_file.write(f'{group_id},{count}\n')
            el_count += 1
    all_group_ids.update(group_ids)

sbm_file.close()
print(
    f'Created SBMClone input file with {len(all_group_ids)} cells, {count + 1} mutations and {el_count} matrix elements')
# Out:
# Creating SBMClone input file...
# Created SBMClone input file with 410 cells, 10551 mutations and 47627 matrix elements

# %%
# Parse the SBM Clone output (run via 'python ~/work/sbmclone/sbmclone.py sbm_input'), assign the clusters
# to cells and compare to the Chisel ground truth clustering (via the ARI score)

from sklearn.metrics import adjusted_rand_score as ari

print('Mapping back SBMClone output to cell ids and comparing with Chisel ground truth')
sbm_group_clusters = open('/Users/dd/work/svc/data/output/cluster-assignments_9x.txt').readline().split(',')
print(f'SBMClone clustered {len(sbm_group_clusters)} cell groups')
print(f'Expanding group clustering to {len(cell_id_to_clone_idx)} cells...')

sbm_cell_clusters = [None] * len(cell_id_to_idx)
print(cell_id_to_group)
for cell_id, cell_idx in cell_id_to_idx.items():
    sbm_cell_clusters[cell_idx] = sbm_group_clusters[cell_id_to_group[cell_idx_to_id[cell_idx]]]

open(f'/Users/dd/work/svc/data/output/cluster-assignments-per-cell_9x.txt', 'w').write(','.join(sbm_cell_clusters))

print('Evaluating SBMClone performance...')
chisel_clusters = []
for i, cluster in enumerate(sbm_cell_clusters):
    cell_id = cell_idx_to_id[i]
    chisel_clusters.append(cell_id_to_clone_idx[cell_id])
print(f'ARI Score {ari(sbm_cell_clusters, chisel_clusters)}')
# Out:
# Mapping back SBMClone output to cell ids and comparing with Chisel ground truth
# SBMClone clustered 455 cell groups
# Expanding group clustering to 5963 cells...
# {'C-GGCTGGTCACCCTCTA': 0, 'E-TATGCCCCAGAACAGC': 0, 'B-GATGAAAAGCTGTCTA': 0, 'D-CTCGGGACACTGCGCA': 0, 'C-TTCTCCTCATACAGAA': 0, 'B-CTAGTGAGTCGAATCT': 0, 'B-AGTGAGGGTGTGTATC': 0, 'A-TTGGAACGTGCATCTA': 0, 'C-TCCCGATTCTGGGACC': 0, 'B-TGTGTTTAGAAACCTA': 0, 'B-TACTCATCAATCTCTT': 1, 'E-CTCGAAACAAGGTCGA': 1, 'D-CGATTGACAACTCATG': 1, 'B-CAGGTGCGTCCTCGGA': 1, 'D-TTGAACGCACCTTGCT': 1, 'E-TAAGCGTAGGACAGTC': 1, 'C-ACCTTTATCTACCGAA': 1, 'E-GCATACACAACAACTC': 1, 'E-AATCCAGAGAATTGTG': 1, 'C-CAGCAGCCAACAACTC': 1, 'C-TGAGCCGAGTTTGGCT': 2, 'E-CGTAGGCAGACTGGGT': 2, 'C-TCTGAGACAAGGTATA': 2, 'E-TGACTTTTCTCGTCTG': 2, 'E-TCATTACGTGCAACCC': 2, 'D-TAGGCATTCTGATGGT': 2, 'E-TCATTACGTCAAGTCT': 2, 'B-GTGCATAAGTACGTTC': 2, 'B-GAGGTGAAGGCTCTTA': 2, 'D-ATTTCTGGTCAAGTCT': 2, 'C-TCATTTGAGTGACATA': 3, 'C-GCTTGAATCATTTGCT': 3, 'B-GTTCGGGCATCGCACG': 3, 'D-AAGTCTGCAAATCAGA': 3, 'C-AGCAGCCAGGGCTTGA': 3, 'C-GGGTTGCTCTGGTGGC': 3, 'D-CAAGGCCCAAACGGGT': 3, 'C-TACGGATAGTGTTTGC': 3, 'B-AAATGCCGTTACGCCG': 3, 'D-CAGCTAAGTAACTGTC': 3, 'E-CTTAGGAAGGCAGTCA': 4, 'E-TGAGCATGTACTACAC': 4, 'E-ACCCACTGTCAGGTAG': 4, 'E-TAGACCATCCGTTCAC': 4, 'D-CCTTACGAGGACCAGT': 4, 'E-TGCGGGTAGGAGTTGC': 4, 'B-TACCTTATCTACAGTG': 4, 'E-CAAGTTGCAGATGAAT': 4, 'C-ACCGTAAGTCATACCA': 4, 'B-CGTCTACGTAAGATGT': 4, 'D-GATCAGTGTGCTTTGA': 5, 'C-TCGTACCCATCACTGA': 5, 'C-CGAGCCACAACAGCCC': 5, 'D-ATCGAGTTCGGTGCAC': 5, 'B-TGCCCATAGCGCTCAC': 5, 'D-GTTACAGGTCCAAGTT': 5, 'B-TGCGGGTCAGCGCATC': 5, 'B-CTCGTACGTGTTTCAG': 5, 'D-CACAGTAGTGGCCTGT': 5, 'D-CCGTACTGTGGTTCTA': 5, 'D-CAGCAGCGTTGAGCAG': 6, 'D-CTTCTCTCAGTGGATG': 6, 'D-ACTATCTAGAAGCCCA': 6, 'B-CCGGGATCACGACTAT': 6, 'D-TTTCCTCAGCTGTCTA': 6, 'C-TCGAGGCTCTCAGTTT': 6, 'B-TCATTACAGAAACCTA': 6, 'C-ACGATACCAAATACGA': 6, 'D-GCTGCGATCAGGACAG': 6, 'D-GACGGCTTCTGGGCAC': 6, 'D-AGAGCGACATCCTGGG': 7, 'D-TCGGGACTCGTTCGGG': 7, 'E-TAGTTGGCACGATCTA': 7, 'D-TGACAACAGGCTCTTA': 7, 'B-AATCGGTAGATTGAGT': 7, 'E-ATAGACCTCGCGCACA': 7, 'C-TCACGAATCGTTACTT': 7, 'D-ATGTGTGCACGTGGCT': 7, 'D-ATGCGATTCCACAGAT': 7, 'C-TACTTACGTAGGATAT': 7, 'D-GCGCGATGTGCTCGAC': 8, 'C-CCCATACCAAGTGACG': 8, 'B-GGACAAGCACACGCAC': 8, 'B-TGGACGCAGCCCAATT': 8, 'D-CCCAATCAGTGAAGAG': 8, 'D-TTAGTTCGTGTCCCTT': 8, 'D-TGCCAAACACCAATAC': 8, 'E-GTATCTTGTAACTTCG': 8, 'B-GACCAATTCCAACGAT': 8, 'C-TACTCGCCACGTGCGT': 8, 'E-GGTGAAGGTGTGACAG': 9, 'E-GTATTCTGTTAAGTAG': 9, 'E-GACCAATCATTACTTC': 9, 'D-ACACCCTGTTGGTGAG': 9, 'E-ACGCCGATCAACTGCA': 9, 'D-CTGAAGTCACGATAGG': 9, 'E-AAACGGGAGTCTAGCT': 9, 'E-GACAGAGGTCAGGTAG': 9, 'E-TGCGCAGTCGTTCGAA': 9, 'E-TTCTCAACACGACGCT': 9, 'C-CCACCTAGTGGCAAAC': 10, 'D-GAAACTCGTGACCAAG': 10, 'D-TCGAGGCCAACGCCGT': 10, 'D-AGCTCCTGTACCTAGT': 10, 'B-TTTCCTCCAGGGAAGG': 10, 'E-TGACAACCACGCGATC': 10, 'B-TAAGAGAGTCGCGTAC': 10, 'C-AACTGGTTCTGCACAA': 10, 'C-TCGAGGCAGTGGGATC': 10, 'E-GTTCGGGTCATGCGCG': 10, 'D-TAGACCACAACGGGAT': 11, 'C-TGACAACGTGCGCTTG': 11, 'E-TTTGCGCGTCCAAGTT': 11, 'E-TGACTTTTCCTGAAGT': 11, 'B-CCAGCGACACACGTGC': 11, 'B-ACGGGCTAGAGTTGGC': 11, 'C-GGTGAAGTCTCTAGTT': 11, 'C-ATTCTACCACGTTTAG': 11, 'C-ACACCAAGTCAAGTCT': 11, 'D-TAGGCATGTGGTTCTA': 11, 'B-ATGCGATCAAACTCAC': 12, 'B-GGGATGATCGGCTCAG': 12, 'C-CACAGGCTCATCGCGG': 12, 'C-CGCGGTACATCAGGGA': 12, 'D-CAAGTTGGTATATGAG': 12, 'D-CCATGTCCACATCTAG': 12, 'C-CGGGTCAAGAGACGAA': 12, 'C-CTCGAGGTCTCAGATG': 12, 'E-AAGACCTTCAATAGGA': 12, 'E-TGAAAGATCCTCAGTC': 12, 'C-TACTCATAGTGGTTAA': 13, 'C-GCGAGAACAGACACGA': 13, 'E-CTGCTGTGTGTTTCAG': 13, 'B-ACCGTAAAGGGATCTG': 13, 'D-CGTCCATAGGCCGAAT': 13, 'B-CAAGATCAGTTCGATC': 13, 'E-ATAAGAGTCCCACAAA': 13, 'B-GTGCGGTGTACCTCGG': 13, 'E-ATTGGACTCCCAAAGT': 13, 'B-TTGGAACAGGGTAACC': 13, 'D-GAAACTCGTGTGCTTA': 14, 'E-AACGTTGTCAGAGTAA': 14, 'B-ACGCCGACATTATCGG': 14, 'E-GTCACAAGTACTGCTA': 14, 'B-GGCCGATTCTACGGCG': 14, 'B-ACTGCTCGTGCACACC': 14, 'E-TGCTGCTAGACAAAGG': 14, 'E-CTACATTGTGATTACC': 14, 'E-GAACATCTCTTCACGC': 14, 'E-CTGCCTAAGAGACTTA': 14, 'D-TAAGCGTAGGATCCTT': 15, 'D-ACACCAAGTGGTCAAG': 15, 'C-GTACGTAGTCGACGCT': 15, 'E-AAGACCTGTAAGCGCA': 15, 'B-TGACAACAGAGCTGGT': 15, 'C-TAGGCATCAACGCTTA': 15, 'D-AAGGAGCTCTCGAACA': 15, 'D-CACCACTTCATCAG ...
# Evaluating SBMClone performance...
# ARI Score 0.005410192946418294

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import seaborn as sns


def tick_format(tick, pos):
    print(tick, pos)
    return "bla"


pal = sns.color_palette("magma")

fig, axs = plt.subplots(1, figsize=(12, 6))

xfill = [0, .05]
y1fill = [0, 0]
y2fill = [1, 1]

x_ticks = [0.03, 0.06, 0.09, 0.12, 0.15, 0.18, 0.21, 0.24, 0.27, 0.3]

sbm_clone = [-0.0001, -6.321868604628362e-05, 0.3226, 0.4066, 0.6202, 0.5193, 0.704,  0.7150, 0.7021, 0.6996]

secedo = [0.6, 0.6, 0.6, 0.7, 0.8, 0.9, 0.9, 0.9, 0.9, 0.9]

axs.plot(x_ticks, secedo, label="SBMClone", marker='o', color=pal[5])
axs.plot(x_ticks, sbm_clone, label="Secedo", marker='o', color=pal[3])

plt.xticks(x_ticks, fontsize=14)
plt.yticks(fontsize=14)

axs.set_ylim([0, 1])
axs.set_xlim([0, 0.3])
axs.xaxis.set_major_locator(ticker.FixedLocator(x_ticks))
axs.xaxis.set_minor_locator(ticker.NullLocator())
axs.xaxis.set_ticklabels(x_ticks, rotation=90)
#axs.grid(True)
axs.legend(loc='best', fontsize=14)

plt.fill_between(xfill, y1fill, y2fill, facecolor='blue', alpha=0.05)
plt.xlabel("Avg. per-cell coverage")

plt.ylabel("ARI Score")

plt.savefig('/tmp/sbm_clone_compare.pdf', format='pdf', bbox_inches='tight')

plt.show()
